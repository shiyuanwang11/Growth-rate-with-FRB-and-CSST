# %% [markdown]
# ### more plot

# %%
import ex_func
import numpy as np
import Func
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# array([1.e+02, 1.e+04, 1.e+06, 1.e+08])
z1_err100, z1_err300, z1_err1000=ex_func.get_err(0.15)
z2_err100, z2_err300, z2_err1000=ex_func.get_err(0.45)
z3_err100, z3_err300, z3_err1000=ex_func.get_err(0.75)

def rgba(cc):
    return cc/255.
c1 = rgba(np.array([189.,142.,192.,255.]))
c2 = rgba(np.array([111.,128.,190.,255.]))
c3 = rgba(np.array([244.,126.,98.,255.]))

# %%
err100_w = np.zeros(len(z1_err100))
err100_om = np.zeros(len(z1_err100))
err100_sig8 = np.zeros(len(z1_err100))
err100_s8 = np.zeros(len(z1_err100))
for i in range(len(z1_err100)):
    err100_w[i], err100_om[i], err100_sig8[i], err100_s8[i] = ex_func.get_para(np.array([z1_err100[i],z2_err100[i],z3_err100[i]]))

err300_w = np.zeros(len(z1_err100))
err300_om = np.zeros(len(z1_err100))
err300_sig8 = np.zeros(len(z1_err100))
err300_s8 = np.zeros(len(z1_err100))
for i in range(len(z1_err100)):
    err300_w[i], err300_om[i], err300_sig8[i], err300_s8[i] = ex_func.get_para(np.array([z1_err300[i],z2_err300[i],z3_err300[i]]))

err1000_w = np.zeros(len(z1_err100))
err1000_om = np.zeros(len(z1_err100))
err1000_sig8 = np.zeros(len(z1_err100))
err1000_s8 = np.zeros(len(z1_err100))
for i in range(len(z1_err100)):
    err1000_w[i], err1000_om[i], err1000_sig8[i], err1000_s8[i] = ex_func.get_para(np.array([z1_err1000[i],z2_err1000[i],z3_err1000[i]]))
# Out:
# [output] Output to be read-from/written-into folder 'chains', with prefix 'joint'
# [loglike] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: omegam:0.197653, sigma8:0.9723455, w:-1.584911
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {loglike: 273.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-05-23 20:23:55 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.026
# [mcmc]  - Convergence of means: R-1 = 1.742421 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# ...

# %%
err100_w_s = gaussian_filter1d(err100_w, sigma=2)
err300_w_s = gaussian_filter1d(err300_w, sigma=2)
err1000_w_s = gaussian_filter1d(err1000_w, sigma=2)

err100_om_s = gaussian_filter1d(err100_om, sigma=2)
err300_om_s = gaussian_filter1d(err300_om, sigma=2)
err1000_om_s = gaussian_filter1d(err1000_om, sigma=2)

err100_sig8_s = gaussian_filter1d(err100_sig8, sigma=2)
err300_sig8_s = gaussian_filter1d(err300_sig8, sigma=2)
err1000_sig8_s = gaussian_filter1d(err1000_sig8, sigma=2)

err100_s8_s = gaussian_filter1d(err100_s8, sigma=2)
err300_s8_s = gaussian_filter1d(err300_s8, sigma=2)
err1000_s8_s = gaussian_filter1d(err1000_s8, sigma=2)

# %%
planck_fish = np.array([[ 2.17072062e+09, -1.90598633e+09,  5.34704389e+08,
         8.30179107e+05, -7.66609692e+07, -7.20267526e+07,
        -9.64590415e+06,  2.74596215e+07,  3.45062621e+07,
         1.52993246e+08],
       [-1.90598633e+09,  1.74335394e+09, -4.94290055e+08,
        -1.98445746e+05,  6.93889378e+07,  6.56360101e+07,
         8.92883793e+06, -2.50054924e+07, -3.09952706e+07,
        -1.39598805e+08],
       [ 5.34704389e+08, -4.94290055e+08,  1.57305184e+08,
         1.60040206e+05, -1.91317119e+07, -1.81557008e+07,
        -2.98559737e+06,  7.07019502e+06,  7.25502267e+06,
         3.99655572e+07],
       [ 8.30179107e+05, -1.98445746e+05,  1.60040206e+05,
         1.62588492e+05, -8.90857077e+04, -3.05915258e+04,
        -1.40775681e+03,  5.34823610e+03,  8.64867873e+03,
         3.05024774e+04],
       [-7.66609692e+07,  6.93889378e+07, -1.91317119e+07,
        -8.90857077e+04,  2.89821376e+06,  2.69953249e+06,
         2.91711802e+05, -1.00150400e+06, -1.45786252e+06,
        -5.52224868e+06],
       [-7.20267526e+07,  6.56360101e+07, -1.81557008e+07,
        -3.05915258e+04,  2.69953249e+06,  2.65038156e+06,
         2.74877217e+05, -9.43139274e+05, -1.37193637e+06,
        -5.19925401e+06],
       [-9.64590415e+06,  8.92883793e+06, -2.98559737e+06,
        -1.40775681e+03,  2.91711802e+05,  2.74877217e+05,
         9.18530226e+04, -1.25227898e+05, -4.98835436e+02,
        -7.48668490e+05],
       [ 2.74596215e+07, -2.50054924e+07,  7.07019502e+06,
         5.34823610e+03, -1.00150400e+06, -9.43139274e+05,
        -1.25227898e+05,  3.75945432e+05,  4.62620786e+05,
         1.99254823e+06],
       [ 3.45062621e+07, -3.09952706e+07,  7.25502267e+06,
         8.64867873e+03, -1.45786252e+06, -1.37193637e+06,
        -4.98835436e+02,  4.62620786e+05,  1.09946720e+06,
         2.36629718e+06],
       [ 1.52993246e+08, -1.39598805e+08,  3.99655572e+07,
         3.05024774e+04, -5.52224868e+06, -5.19925401e+06,
        -7.48668490e+05,  1.99254823e+06,  2.36629718e+06,
         1.12174236e+07]])
# ["omegam", "sigma8"]
rsd_fish = np.array([[  30.20200579, -192.07318699, -114.12502183],
       [-192.07318699, 2024.64107128,  858.61920149],
       [-114.12502183,  858.61920149,  496.05759245]])

mean = np.array([ 0.02239316,  0.11992714,  1.04093817,  0.05393335,  3.04338637,
        0.96539223, -1.58491121,  0.19765297,  0.97234554,  0.77748323])

def add_matrix_elements(a, b):
    # 创建矩阵a的副本
    result = np.copy(a)
    result[6:9, 6:9] += b
    return result

planck_rsd_fish = add_matrix_elements(planck_fish, rsd_fish)

planck_cov = np.linalg.inv(planck_fish)
planck_rsd_cov = np.linalg.inv(planck_rsd_fish)

# %% [markdown]
# ### 未平滑

# %%
err_planck_w = np.sqrt(planck_cov[6,6])
err_planck_rsd_w = np.sqrt(planck_rsd_cov[6,6])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)
plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_w),'b-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_w),'r-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_w),'g-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_w,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_w,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(w) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %%
err_planck_om = np.sqrt(planck_cov[7,7])
err_planck_rsd_om = np.sqrt(planck_rsd_cov[7,7])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_om),'b-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_om),'r-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_om),'g-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_om,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_om,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(\Omega_m) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %%
err_planck_sig8 = np.sqrt(planck_cov[8,8])
err_planck_rsd_sig8 = np.sqrt(planck_rsd_cov[8,8])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)
plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_sig8),'b-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_sig8),'r-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_sig8),'g-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_sig8,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_sig8,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(\sigma_8) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %%
err_planck_s8 = np.sqrt(planck_cov[9,9])
err_planck_rsd_s8 = np.sqrt(planck_rsd_cov[9,9])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_s8),'b-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_s8),'r-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_s8),'g-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_s8,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_s8,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(S_8) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### w

# %%
err_planck_w = np.sqrt(planck_cov[6,6])
err_planck_rsd_w = np.sqrt(planck_rsd_cov[6,6])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)#.take([2,6,10,14])

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_w_s),c=c1,linestyle='-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_w_s),c=c2,linestyle='-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_w_s),c=c3,linestyle='-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_w,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_w,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(w) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### om

# %%
err_planck_om = np.sqrt(planck_cov[7,7])
err_planck_rsd_om = np.sqrt(planck_rsd_cov[7,7])
err100_om, err300_om, err1000_om

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)#.take([2,6,10,14])

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_om_s),c=c1,linestyle='-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_om_s),c=c2,linestyle='-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_om_s),c=c3,linestyle='-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_om,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_om,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(\Omega_m) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### sig8

# %%
err_planck_sig8 = np.sqrt(planck_cov[8,8])
err_planck_rsd_sig8 = np.sqrt(planck_rsd_cov[8,8])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)#.take([2,6,10,14])

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_sig8_s),c=c1,linestyle='-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_sig8_s),c=c2,linestyle='-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_sig8_s),c=c3,linestyle='-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_sig8,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_sig8,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(\sigma_8) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### s8

# %%
err_planck_s8 = np.sqrt(planck_cov[9,9])
err_planck_rsd_s8 = np.sqrt(planck_rsd_cov[9,9])

Nfrb = np.logspace(1, 9, num=17, endpoint=True, base=10.0, dtype=None)#.take([2,6,10,14])

plt.clf()
plt.figure(figsize=(10, 5))
plt.plot(Nfrb,np.sqrt(err100_s8_s),c=c1,linestyle='-',label='Planck + RSD + ksz tomography(100)')
plt.plot(Nfrb,np.sqrt(err300_s8_s),c=c2,linestyle='-',label='Planck + RSD + ksz tomography(300)')
plt.plot(Nfrb,np.sqrt(err1000_s8_s),c=c3,linestyle='-',label='Planck + RSD + ksz tomography(1000)')
plt.axhline(y=err_planck_rsd_s8,label='RSD+Planck',c='grey', linestyle='-.')
plt.axhline(y=err_planck_s8,label='Planck',c='black', linestyle='--')
plt.xlabel(r'$ N_{FRB} $',size=13)
plt.ylabel(r'$ \sigma(S_8) $',size=13)
plt.legend(fontsize=13)
#plt.xlim([1e+2,1e+9])
plt.xscale('log')
plt.yscale('log')
